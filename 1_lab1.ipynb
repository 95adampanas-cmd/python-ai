# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %% [markdown]
# importujemy api z pliku.env

# %%
# First let's do an import
from dotenv import load_dotenv

# %% [markdown]
# uruchamiamy funkcje z pobraniem api

# %%
# Next it's time to load the API keys into environment variables

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# sprawdzenie czy api działa

# %%
# Check the keys

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting guide

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder!
# If you get a NameError - head over to the guides folder to learn about NameErrors

openai = OpenAI()

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 equals 4.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# A bat and a ball cost $1.10 in total. The bat costs $1.00 more than the ball. How much does the ball cost?

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's denote the cost of the ball as \( x \) dollars.
#
# According to the problem:
# - The bat costs $1.00 more than the ball, so the bat costs \( x + 1.00 \).
# - Together, their cost is $1.10.
#
# Set up the equation:
# \[
# x + (x + 1.00) = 1.10
# \]
#
# Combine like terms:
# \[
# 2x + 1.00 = 1.10
# \]
#
# Subtract 1.00 from both sides:
# \[
# 2x = 0.10
# \]
#
# Divide both sides by 2:
# \[
# x = 0.05
# \]
#
# **Answer:** The ball costs **5 cents**.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let's denote the cost of the ball as \( x \) dollars.
#
# According to the problem:
# - The bat costs $1.00 more than the ball, so the bat costs \( x + 1.00 \).
# - Together, their cost is $1.10.
#
# Set up the equation:
# \[
# x + (x + 1.00) = 1.10
# \]
#
# Combine like terms:
# \[
# 2x + 1.00 = 1.10
# \]
#
# Subtract 1.00 from both sides:
# \[
# 2x = 0.10
# \]
#
# Divide both sides by 2:
# \[
# x = 0.05
# \]
#
# **Answer:** The ball costs **5 cents**.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Wybierz jedną branżę, która może być interesującym polem do wdrożenia rozwiązań z użyciem Agentic AI."}]

# Then make the first call:

response = openai.chat.completions.create(

   model="gpt-4.1-mini",
messages=messages

)



# Then read the business idea:

business_idea = response.choices[0].message.content
print(business_idea)

# And repeat!
# Out:
# Branża zdrowia (medycyna) wydaje się być szczególnie interesującym polem do wdrożenia rozwiązań z użyciem Agentic AI.
#
# Agentic AI, czyli sztuczna inteligencja z autonomicznymi zdolnościami podejmowania decyzji i działania, może w medycynie wspierać zarówno diagnostykę, jak i leczenie pacjentów. Przykładowo:
#
# - **Diagnozowanie chorób:** Agentic AI może analizować dane medyczne (wyniki badań, historie chorób, obrazy medyczne) i samodzielnie proponować wstępne diagnozy, które następnie są weryfikowane przez lekarza.
# - **Personalizacja leczenia:** AI może samodzielnie dobierać optymalne terapie na podstawie indywidualnych cech pacjenta, monitorować ich efekty i dostosowywać leczenie w czasie rzeczywistym.
# - **Wsparcie w operacjach chirurgicznych:** Roboty chirurgiczne sterowane przez Agentic AI mogą działać z wysoką precyzją, minimalizując błędy i skracając czas zabiegów.
# - **Zarządzanie opieką:** AI może autonomicznie planować i koordynować działania związane z opieką nad pacjentem, np. umawianie wizyt, przypominanie o lekach, analizowanie ryzyka powikłań.
#
# Dzięki takim zastosowaniom możliwe jest zwiększenie efektywności systemu opieki zdrowotnej, poprawa jakości diagnoz i leczenia oraz redukcja kosztów. Ponadto, medycyna to obszar, gdzie dokładność, szybkość oraz ciągły monitoring mają kluczowe znaczenie, co dobrze współgra z możliwością autonomicznego działania AI.

# %%
# Drugi krok: dodajemy nową wiadomość DO TEJ SAMEJ HISTORII rozmowy
messages.append({"role": "user", "content": "Wybierz jedną branżę, która może być interesującym polem do wdrożenia rozwiązań z użyciem Agentic AI."})
messages.append({"role": "assistant", "content": business_idea})
messages.append({"role": "user", "content": "Podaj konkretny problem w tej branży, który mógłby być rozwiązany przez Agentic AI."})

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

pain_point = response.choices[0].message.content
print("Problem:", pain_point)
# Out:
# Problem: Konkretnym problemem w branży zdrowia, który mógłby być rozwiązany przez Agentic AI, jest **wczesne wykrywanie i monitorowanie sepsy u pacjentów hospitalizowanych**.
#
# ### Dlaczego to ważny problem?
# Sepsa to szybkie, potencjalnie śmiertelne zakażenie, które wymaga natychmiastowej interwencji. Jej wczesne rozpoznanie i odpowiednia reakcja medyczna znacząco zwiększają szanse na przeżycie i zmniejszają ryzyko powikłań. Niestety, objawy sepsy często są niespecyficzne, a jej diagnoza bywa trudna i opóźniona, co prowadzi do wysokiej śmiertelności.
#
# ### Jak Agentic AI może rozwiązać ten problem?
# - **Autonomiczne monitorowanie pacjentów:** Agentic AI może na bieżąco analizować dane z różnych źródeł (parametry życiowe, wyniki badań laboratoryjnych, obrazowanie medyczne) i wykrywać wczesne sygnały ostrzegawcze sepsy, zanim lekarze zauważą ich sumę.
# - **Samodzielne podejmowanie decyzji o interwencji:** AI może automatycznie generować alerty, a nawet inicjować protokoły interwencyjne (np. zamówienie dodatkowych badań, powiadomienie zespołu medycznego) w trybie 24/7.
# - **Personalizacja leczenia:** Algorytmy mogą na bieżąco dostosowywać terapię antybiotykową i płynoterapię w odpowiedzi na zmieniający się stan pacjenta.
# - **Zarządzanie ryzykiem:** Agentic AI może identyfikować pacjentów o najwyższym ryzyku rozwinięcia sepsy i monitorować ich jeszcze uważniej, co pozwoli na zapobieganie krytycznym sytuacjom.
#
# Dzięki temu możliwe jest znaczne skrócenie czasu reakcji medycznej, poprawa wyników leczenia i zmniejszenie liczby zgonów związanych z sepsą.

# %%
messages.append({"role": "user", "content": "Wybierz jedną branżę, która może być interesującym polem do wdrożenia rozwiązań z użyciem Agentic AI."})
messages.append({"role": "assistant", "content": business_idea})
messages.append({"role": "user", "content": "Podaj konkretny problem w tej branży, który mógłby być rozwiązany przez Agentic AI."})
messages.append({"role": "assistant", "content": pain_point})
messages.append({"role": "user", "content": "Zaproponuj rozwiązanie Agentic AI dla tego problemu"})

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

solution = response.choices[0].message.content
print("Problem:", solution)
# Out:
# Problem: Proponuję rozwiązanie Agentic AI w postaci autonomicznego systemu do wczesnego wykrywania i zarządzania sepsą, które można nazwać **SepsiaGuard AI**.
#
# ### Opis rozwiązania SepsiaGuard AI:
#
# #### 1. Zbieranie danych w czasie rzeczywistym
# - System integruje się z istniejącymi szpitalnymi systemami informatycznymi (Electronic Health Records, systemy monitoringu pacjentów).
# - Na bieżąco zbiera dane o pacjencie: parametry życiowe (tętno, ciśnienie, saturacja, temperatura), wyniki badań laboratoryjnych (np. leukocytoza, poziom białka C-reaktywnego), dane z obrazowania, historię chorób i bieżące leczenie.
#
# #### 2. Analiza i wykrywanie wczesnych objawów sepsy
# - Wykorzystuje zaawansowane modele uczenia maszynowego i algorytmy uczenia głębokiego do wykrywania wzorców wskazujących na rozwijającą się sepsę.
# - System działa w trybie agentowym, czyli niezależnie od interwencji człowieka analizuje dane, prognozuje ryzyko rozwoju sepsy i ocenia dynamikę zmian.
#
# #### 3. Autonomiczne alerty i inicjowanie działań
# - Po wykryciu ryzyka przekraczającego zdefiniowany próg, system generuje automatyczne alerty skierowane do personelu medycznego – w formie notyfikacji w systemie szpitalnym, SMS lub aplikacji mobilnej.
# - W bardziej zaawansowanym wariancie system może samodzielnie inicjować zamówienie dodatkowych badań (lab), rezerwować konsultacje specjalistyczne lub uruchamiać protokoły terapeutyczne zatwierdzone wcześniej przez lekarzy (np. zalecaną płynoterapię lub podanie antybiotyków).
#
# #### 4. Ciągłe monitorowanie i adaptacja terapii
# - System śledzi skuteczność podjętych działań, analizuje zmiany w stanie pacjenta i odpowiednio dostosowuje zalecenia terapeutyczne, a w razie potrzeb informuje o konieczności dalszych interwencji.
# - Agentic AI uczy się na bieżąco na podstawie nowych przypadków, poprawiając efektywność diagnozy i leczenia.
#
# #### 5. Raportowanie i wsparcie decyzyjne
# - Tworzy raporty dla lekarzy i personelu medycznego na temat stanu pacjenta, przebiegu terapii i ryzyka powikłań.
# - Wspiera decyzje lekarskie, nie zastępując ich całkowicie, ale znacząco zmniejszając ryzyko opóźnień i błędów.
#
# ---
#
# ### Korzyści SepsiaGuard AI:
# - **Skrócenie czasu rozpoznania sepsy – czas jest kluczowy w ratowaniu życia.**
# - **Zmniejszenie liczby błędów i przeoczeń przez lekarzy w warunkach dużego obciążenia pracą.**
# - **Poprawa wyników leczenia i zmniejszenie śmiertelności z powodu sepsy.**
# - **Optymalizacja wykorzystania zasobów medycznych (badania, konsultacje).**
# - **Wsparcie personelu medycznego, zwłaszcza na oddziałach o dużym natężeniu pacjentów (np. intensywna terapia, oddziały chirurgiczne).**
#
# Dzięki autonomicznym cechom Agentic AI system SepsiaGuard AI może działać niezależnie, szybko reagować na zmieniające się dane, a jednocześnie współpracować z ludźmi, zapewniając efektywne i bezpieczne zarządzanie jednym z największych wyzwań współczesnej medycyny.

# %%
# Krok 1: zapytaj o branżę
messages = [{"role": "user", "content": "Wybierz jedną branżę, która może być interesującym polem do wdrożenia rozwiązań z użyciem Agentic AI."}]

response = openai.chat.completions.create(
   model="gpt-4.1-mini",
   messages=messages
)

business_idea = response.choices[0].message.content
print("📌 Branża:", business_idea)

# Krok 2: zapytaj o problem w tej branży
messages.append({"role": "assistant", "content": business_idea})
messages.append({"role": "user", "content": "Podaj konkretny problem w tej branży, który mógłby być rozwiązany przez Agentic AI."})

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

pain_point = response.choices[0].message.content
print("⚠️ Problem:", pain_point)

# Krok 3: zapytaj o rozwiązanie dla tego problemu
messages.append({"role": "assistant", "content": pain_point})
messages.append({"role": "user", "content": "Zaproponuj rozwiązanie Agentic AI dla tego problemu"})

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

solution = response.choices[0].message.content
print("🤖 Rozwiązanie:", solution)
# Out:
# 📌 Branża: Jedną z bardzo interesujących branż do wdrożenia rozwiązań z użyciem Agentic AI jest **opieka zdrowotna**.
#
# Agentic AI może znacząco usprawnić zarządzanie procesami medycznymi, wspomagać diagnostykę, personalizować terapie oraz automatyzować rutynowe zadania administracyjne. Przykładowe zastosowania to:
#
# - **Wsparcie w diagnozie i analizie danych medycznych** – AI może samodzielnie przeszukiwać bazy danych, literaturę medyczną czy wyniki badań, aby zasugerować potencjalne rozpoznania lub wskazać istotne korelacje.
# - **Zarządzanie ścieżkami leczenia** – AI może monitorować stan pacjenta i na bieżąco dostosowywać zalecenia terapeutyczne, reagując dynamicznie na zmiany.
# - **Automatyzacja administracji** – tworzenie dokumentacji medycznej, zarządzanie terminami wizyt, przypomnienia dla pacjentów, optymalizacja harmonogramów.
# - **Telemedycyna i asystenci dla lekarzy** – agent może komunikować się z pacjentem, zbierać objawy, udzielać zaleceń lub kierować do odpowiednich specjalistów.
#
# Dzięki temu Agentic AI nie tylko zwiększa efektywność działań, ale także może podnieść jakość opieki i skrócić czas reakcji, co jest kluczowe w medycynie.
# ⚠️ Problem: Konkretnym problemem w branży opieki zdrowotnej, który mógłby być rozwiązany przez Agentic AI, jest **opóźnienie i niedokładność w analizie wyników badań diagnostycznych oraz podejmowaniu decyzji terapeutycznych**.
#
# ### Opis problemu:
# W placówkach medycznych lekarze często mają ograniczony czas na przeglądanie wyników badań (np. obrazowych, laboratoryjnych), co może prowadzić do przeoczenia istotnych szczegółów lub opóźnień w diagnozie. Dodatkowo, analiza dużej ilości danych z różnych źródeł (wyniki, historia choroby, literatura medyczna) jest czasochłonna i złożona.
#
# ### Jak Agentic AI może pomóc:
# - Agentic AI mógłby samodzielnie analizować wyniki badań diagnostycznych (np. obrazy medyczne, wyniki krwi), porównywać je z historią medyczną pacjenta oraz aktualną literaturą naukową.
# - Agent mógłby automatycznie wykrywać potencjalne nieprawidłowości, sugerować możliwe diagnozy lub dodatkowe testy do wykonania.
# - Na podstawie zgromadzonych informacji AI mogłaby rekomendować optymalne ścieżki leczenia, uwzględniając indywidualne cechy pacjenta.
# - W przypadku wykrycia pilnych przypadków, agent mógłby natychmiast powiadomić odpowiedni personel medyczny, co skróci czas reakcji.
#
# Dzięki temu proces diagnostyczny i terapeutyczny byłby szybszy, dokładniejszy i bardziej zindywidualizowany, co może przekładać się na lepsze efekty leczenia i zmniejszenie ryzyka powikłań.
# 🤖 Rozwiązanie: ### Propozycja rozwiązania Agentic AI dla problemu opóźnień i niedokładności w analizie wyników badań diagnostycznych oraz podejmowaniu decyzji terapeutycznych:
#
# #### Nazwa systemu: **MediAgent**
#
# ---
#
# ### Architektura i funkcje MediAgent:
#
# 1. **Automatyczna agregacja i analiza danych medycznych**
#    - MediAgent integruje się z systemami szpitalnymi (np. elektroniczną dokumentacją medyczną, systemami PACS do obrazów medycznych, laboratoriami).
#    - AI przetwarza i interpretuje wyniki badań, np. obrazy rentgenowskie, tomografie, wyniki badań krwi.
#    - Korzysta z modeli ML i głębokiego uczenia, wyspecjalizowanych w diagnostyce obrazowej oraz analizie danych numerycznych.
#
# 2. **Kontekstowa interpretacja wyników**
#    - Agent analizuje historię medyczną pacjenta, dotychczasowe diagnozy, aktualne objawy.
#    - Przeszukuje powiązane bazy danych naukowych i wytyczne kliniczne (np. wytyczne WHO, EBM - Evidence-Based Medicine).
#    - Na tej podstawie generuje rekomendacje diagnostyczne i terapeutyczne.
#
# 3. **Proaktywne monitorowanie i przypomnienia**
#    - Agent śledzi przebieg choroby i wyniki kolejnych badań.
#    - Wykrywa odstępstwa od normy i automatycznie przypomina personelowi medycznemu o konieczności ponownej oceny lub dodatkowych badaniach.
#    - W sytuacjach nagłych (np. wykrycie krytycznych parametrów) natychmiast generuje alert i powiadomienia.
#
# 4. **Interaktywny interfejs dla lekarzy**
#    - MediAgent działa jako asystent, dostarczając podsumowania, wizualizacje i wyjaśnienia swoich analiz.
#    - Lekarz może zadawać pytania głosowo lub przez chat, a agent samodzielnie wyszukuje i prezentuje informacje.
#    - System wspiera podejmowanie decyzji, ale ostateczna diagnoza i terapia pozostaje w rękach lekarza.
#
# 5. **Uczenie się i adaptacja**
#    - Agent uczy się na podstawie wyników leczenia i informacji zwrotnych od lekarzy.
#    - Model jest regularnie aktualizowany i dostosowywany do zmieniających się standardów medycznych oraz specyfiki placówki.
#
# ---
#
# ### Przykładowy scenariusz użycia:
#
# Pacjent przychodzi na badania, wyniki obrazowe i laboratoryjne są automatycznie przesyłane do MediAgent. System analizuje dane, wykrywa subtelną anomalię na tomografii oraz podniesione markery zapalne w krwi. Porównuje te informacje z historią pacjenta i najnowszymi publikacjami naukowymi, a następnie proponuje lekarzowi skierowanie na dodatkowe badania i sugeruje możliwą diagnozę. W przypadku potwierdzenia – pomaga zaplanować terapię uwzględniającą indywidualne parametry pacjenta i monitoruje progresję choroby.
#
# ---
#
# ### Korzyści:
#
# - Skrócenie czasu od wykonania badania do uzyskania diagnozy.
# - Zwiększenie dokładności i spójności decyzji medycznych.
# - Odciążenie personelu medycznego od rutynowych analiz i nadzoru.
# - Możliwość wcześniejszej interwencji w sytuacjach krytycznych.
# - Indywidualizacja leczenia na podstawie kompleksowej analizy danych.
#
# ---
#
# Takie rozwiązanie MediAgent oparte na Agentic AI może realnie zwiększyć efektywność i jakość opieki zdrowotnej, szczególnie w dużych szpitalach i ośrodkach diagnostycznych, gdzie liczba pacjentów i złożoność danych jest bardzo wysoka.
